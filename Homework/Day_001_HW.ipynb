# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
#    S&P 500 stock data
#    Historical stock data for all current S&P 500 companies
#    https://www.kaggle.com/camnugent/sandp500#all_stocks_5yr.csv
#    收集近五年全美各公司的歷史資料，含每日最高價、最低價、當日成交量等資訊，可用於回測歷史資料以建立投資策略。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#    作者：Cam Nugent
# 3. 蒐集而來的資料型態為何
#    .csv
# 4. 這組資料想解決的問題如何評估
#    透過近五年的資料，以繪製成圖形的方式，瞭解各股於某個時期的移動平均成本、各股變化。作者期望大家能透過這些資料，最終發展屬於個人的投資策略    以擊敗市場。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#    1. 如何透過數據分析找出載客熱點及時段，規劃最佳路線以節省車輛油耗，進而降低成本。
#    2. 甚麼年齡層會是主要客群
#    3. 哪些是最熱門的載客地點(機場、觀光景點、車站)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#    叫車APP、網頁，利用爬蟲的方式匯總所有資料
#
# 3. 蒐集而來的資料型態為何
#    .Csv
#    時間、日期、路途長短、性別、年齡、目的地
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#    透過每日叫車資訊回饋，紀錄上述所需資料，以迴歸方式進行分析。

# %% [markdown]
# 作業3：

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_square_error(y, y1):
    mse = MSE = ((y-y1)**2).mean()
    return mse

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_square_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 249.447
# The Mean absolute error is 12.732
